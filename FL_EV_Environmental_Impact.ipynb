# %%
# Dependencies for Environment Impact of EV Cars
import csv
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# Path to Datafiles
filepath = 'Environment_Impact_Data_Resources/emissions_residential_sector_COT.csv'

# Read Fuel Impact Data
fuel_impact_data = pd.read_csv(filepath)
fuel_impact_data_df = pd.DataFrame(fuel_impact_data)
fuel_impact_data_df.head()
# Out:
#        Emissions, Residential Sector, MMT CO2 eq.        1990        1991  \
# 0          Fossil fuel combustion: carbon dioxide  338.578020  347.719419
# 1                        Use of fluorinated gases    0.207127    0.453706
# 2  Fossil fuel combustion: other greenhouse gases    6.285643    6.516625
# 3                                           Total  345.070789  354.689750
#
#          1992        1993        1994        1995        1996        1997  \
# 0  353.988691  366.090923  357.049699  353.133577  383.474435  365.033346
# 1    0.453706    0.453706    0.463216    8.689669   10.004783   10.797844
# 2    6.779628    6.067869    5.747232    5.700276    5.975584    4.997469
# 3  361.222025  372.612499  363.260147  367.523521  399.454803  380.828659
#
#          1998  ...        2010        2011        2012        2013  \
# 0  331.610155  ...  334.750883  326.151257  282.366812  329.110636
# 1   10.833751  ...   15.136401   17.460654   19.974936   22.774707
# ...

# %%
fuel_impact_data_df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
fuel_flip = fuel_impact_data_df.T
fuel_flip_df = pd.DataFrame(fuel_flip)
fuel_flip_df["Emissions, Residential Sector, MMT CO2 eq"]=fuel_flip_df.index
fuel_flip_df

fuel_flip = fuel_flip.apply(pd.to_numeric) 

fuel_flip.plot.bar(stacked=True)

# Bar chart of types of fuel and emissions 1990 through 2019
# plt.bar(x=filepath['Emission'],
 
#         height=filepath['years'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Fossil fuel combustion: carbon dioxide"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-f54c2c6df9d8> in <module>
#       4 fuel_flip_df
#       5
# ----> 6 fuel_flip = fuel_flip.apply(pd.to_numeric)
#       7
#       8 fuel_flip.plot.bar(stacked=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ...
